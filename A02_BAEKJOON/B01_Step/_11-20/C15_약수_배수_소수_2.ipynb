# %%
import sys
from io import StringIO

# %%
# 1	1934	 최소공배수
sys.stdin = StringIO('''3
1 45000
6 10
13 17''')

import sys
input = sys.stdin.readline

n = int(input())

for _ in range(n):
    a, b = map(int, input().split())
# Out:
# 1 45000
# 6 10
# 13 17

# %%
# 2	13241	 최소공배수

# %%
# 3	1735	 분수 합

# %%
# 4	2485	 가로수

# %%
# 5	4134	 다음 소수

# %%
# 6	1929	 소수 구하기

# %%
# 7	4948	 베르트랑 공준

# %%
# 8	17103	 골드바흐 파티션

# %%
# 9	13909	 창문 닫기
