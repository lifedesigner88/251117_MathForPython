# %%
from io import StringIO

# %%
# 1	24262	 알고리즘 수업 - 알고리즘의 수행 시간 1
print(1)
print(0)
# Out:
# 1
# 0

# %%
# 2	24263	 알고리즘 수업 - 알고리즘의 수행 시간 2
input = StringIO('''7''').readline

print(int(input()))
print(1)
# Out:
# 7
# 1

# %%
# 3	24264	 알고리즘 수업 - 알고리즘의 수행 시간 3

input = StringIO('''7''').readline

print(int(input())**2)
print(2)
# Out:
# 49
# 2

# %%
# 4	24265	 알고리즘 수업 - 알고리즘의 수행 시간 4
input = StringIO('''7''').readline

n = int(input())
print(int(n*(n-1)/2))
print(2)
# Out:
# 21
# 2

# %%
# 5	24266	 알고리즘 수업 - 알고리즘의 수행 시간 5

input = StringIO('''7''').readline

n = int(input())
print(n**3)
print(3)
# Out:
# 343
# 2

# %%
# 6	24267	 알고리즘 수업 - 알고리즘의 수행 시간 6
input = StringIO('''7''').readline

n = int(input())
print(n*(n-2)*(n-1)//6)
print(3)

# sigma k=1 to (n-2)[sigma z=1 to k [(z)]]
# 조합 방식으로도 풀이가능.
# Out:
# 1

# %%
# 7	24313	 알고리즘 수업 - 점근적 표기 1
