# %%
# 1. 2557 Hello world
print("Hello World!")

# %%
# 2. 1000 A + B
a, b = map(int, input().split())
print(a+b)

# %%
# 3. 1001 A - B
a, b = map(int, input().split())
print(a-b)

# %%
# 4. 10998 A X B
a, b = map(int, input().split())
print(a*b)

# %%
# 5. 1008 A/B
a, b = map(int, input().split())
print(a/b)

# %%
# 6. 10869 사칙연산 
a, b = map(int, input().split())
print(f"{a+b}\n{a-b}\n{a*b}\n{a//b}\n{a%b}")

# %%
# 7. 10926 ??!
s = input()
print(s + "??!")

# %%
# 8. 18108 1998년 생인 내가 태국에서 2541년생?
a = int(input())
print(a-(2541-1998))

# %%
# 9. 10430 나머지

a, b, c = map(int, input().split())
print( (a+b)%c )
print( ( (a%c) + (b%c) )%c )
print( (a*b)%c )
print( ( (a%c) * (b%c) )%c)

# %%
# 10. 2588 곱셈
a = int(input())
b = input()

print(a * int(b[2]))
print(a * int(b[1]))
print(a * int(b[0]))
print(a * int(b))

# %%
# 11. 11382 꼬마 정민
a, b, c = map(int,input().split())

print(a + b + c)

# %%
# 12. 10171 고양이
print(r"""\    /\
 )  ( ')
(  /  )
 \(__)|""")

# %%
# 13. 10172 개
print(r'''|\_/|
|q p|   /}
( 0 )"""\
|"^"`    |
||_/=\\__|''')
