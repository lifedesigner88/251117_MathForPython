# %%
# 1 2739 구구단

a = int(input())
for i in range(1, 10):
    print(a, "*", i, "=", a*i)
# Out:
# 3 * 1 = 2
# 3 * 2 = 4
# 3 * 3 = 6
# 3 * 4 = 8
# 3 * 5 = 10
# 3 * 6 = 12
# 3 * 7 = 14
# 3 * 8 = 16
# 3 * 9 = 18

# %%
# 2.
