# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.linspace(-2, 2, 100)
y = x**2

dx = np.diff(x) + np.delete(x, -1)
dy = np.diff(y)/np.diff(x)

plt.xlim(-2, 2)
plt.ylim(-1, 2)
plt.axis('square')
plt.grid()

plt.plot(x, y, 'b', label='$ y=x^{2} $')
plt.plot(dx, dy, 'r', label=r'$ \frac{dy}{dx} $')

plt.legend().get_texts()[1].set_fontsize(14)

plt.show()
