# %%
from matplotlib.pyplot import *
from numpy import cos, sin, pi

angs = np.random.rand(500)*2*pi

for i in angs:
    plot([0, cos(i)], [0, sin(i)])

axis("square")
xlim([-1, 1])
ylim([-1, 1])
axis("off")
show()
