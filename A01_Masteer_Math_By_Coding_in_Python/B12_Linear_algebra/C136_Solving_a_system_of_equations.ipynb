# %%
from numpy import random
from numpy.linalg import inv
from sympy import Matrix, latex
from sympy.abc import a, b, c
from IPython.display import Math

X = random.randint(1, 10, (3, 3))
y = random.randint(1, 10, (3, 1))

beta = Matrix([a, b ,c])

def dm(m): display(Math(m))
def lm(m): return latex(Matrix(m))

dm(rf"{lm(X)} \times {lm(beta)} = {lm(y)} ")
dm(rf" \qquad \qquad \qquad {lm(beta)} = {lm(X)}^{{-1}} \times \:\; {lm(y)} ")
dm(rf" \qquad \qquad \qquad {lm(beta)} = {lm(inv(X).round(2))} \:\; \times \:\; {lm(y)} ")
dm(rf" \qquad \qquad \qquad {lm(beta)} = {lm((inv(X)@y).round(2))} ")
dm(rf"{lm(X)} \times {lm((inv(X)@y).round(2))} = {lm(y)} ")
dm(rf"{lm( (X@(inv(X)@y)).astype(int))}  = {lm(y)} ")
# Out:
# $\displaystyle \left[\begin{matrix}8 & 3 & 4\\7 & 4 & 1\\3 & 3 & 6\end{matrix}\right] \times \left[\begin{matrix}a\\b\\c\end{matrix}\right] = \left[\begin{matrix}8\\3\\4\end{matrix}\right] $
# $\displaystyle  \qquad \qquad \qquad \left[\begin{matrix}a\\b\\c\end{matrix}\right] = \left[\begin{matrix}8 & 3 & 4\\7 & 4 & 1\\3 & 3 & 6\end{matrix}\right]^{-1} \times \:\; \left[\begin{matrix}8\\3\\4\end{matrix}\right] $
# $\displaystyle  \qquad \qquad \qquad \left[\begin{matrix}a\\b\\c\end{matrix}\right] = \left[\begin{matrix}0.24 & -0.07 & -0.15\\-0.45 & 0.41 & 0.23\\0.1 & -0.17 & 0.13\end{matrix}\right] \:\; \times \:\; \left[\begin{matrix}8\\3\\4\end{matrix}\right] $
# $\displaystyle  \qquad \qquad \qquad \left[\begin{matrix}a\\b\\c\end{matrix}\right] = \left[\begin{matrix}1.13\\-1.43\\0.82\end{matrix}\right] $
# $\displaystyle \left[\begin{matrix}8 & 3 & 4\\7 & 4 & 1\\3 & 3 & 6\end{matrix}\right] \times \left[\begin{matrix}1.13\\-1.43\\0.82\end{matrix}\right] = \left[\begin{matrix}8\\3\\4\end{matrix}\right] $
# $\displaystyle \left[\begin{matrix}8\\3\\4\end{matrix}\right]  = \left[\begin{matrix}8\\3\\4\end{matrix}\right] $
