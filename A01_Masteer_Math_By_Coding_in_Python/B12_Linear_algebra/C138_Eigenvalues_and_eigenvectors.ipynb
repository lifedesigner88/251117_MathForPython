# %%
from matplotlib.pyplot import *
from numpy import array

o = array([0, 0])
a = array([1, 2])

a2 = 2*a

plot(*zip(o, a), 'b-', alpha=.5)
plot(*zip(o, a2), 'r--', alpha=.5)

c = complex(*list(a))
length_a = abs(c)
print(length_a)

c = complex(*list(a2))
length_a2 = abs(c)
print(length_a2)

print(length_a2/length_a)

length = 5
axis('square')
grid()
ylim(-length, length)
xlim(-length, length)
show()
# Out:
# 2.23606797749979
# 4.47213595499958
# 2.0

# %%
from matplotlib.pyplot import *
from numpy import diag
from numpy.random import randint
from numpy.linalg import eig

M = randint(-5, 6, (5, 5))
D = M@M.T


eigvals, eigvecs = eig(D)

dic = {
    "metrix": D,
    "eigenvalues": diag(eigvals),
    "eigenvectors": eigvecs
}

fig, ax = subplots(1, 3, figsize=(8, 4))

for idx, (key, val) in enumerate(dic.items()):
    ax[idx].set_title(key)
    ax[idx].imshow(val)
    ax[idx].axis('off')

show()

# %%
target = 1

Mv = D@eigvecs[:, target]
Iv = eigvals[target]*eigvecs[:, target]

print(eigvecs[:, target])
print(eigvals[target])
print(D)
print(Mv)
print(Iv)
# Out:
# [-0.717214   -0.01623483 -0.24243955 -0.02828539  0.65250557]
# 73.98261371391824
# [[ 56 -16  -4  15 -21]
#  [-16  27   8  -5 -16]
#  [ -4   8  58 -43 -12]
#  [ 15  -5 -43  42  -1]
#  [-21 -16 -12  -1  46]]
# [-53.06136611  -1.20109487 -17.93631175  -2.09262694  48.27406718]
# [-53.06136611  -1.20109487 -17.93631175  -2.09262694  48.27406718]
