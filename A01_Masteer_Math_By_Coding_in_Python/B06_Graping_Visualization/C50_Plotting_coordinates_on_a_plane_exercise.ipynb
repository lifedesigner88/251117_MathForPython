# %%
from matplotlib import pyplot as plt
from sympy import symbols, latex

x= symbols('x')

y = x**2 - 3*x

for i in range(-10, 12):
    plt.plot(i, y.subs(x,i), 'o')


plt.xlabel('x')
plt.ylabel('$ y = %s $' %latex(y))

plt.show()
