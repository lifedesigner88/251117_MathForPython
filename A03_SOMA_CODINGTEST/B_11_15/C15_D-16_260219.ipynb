# %%
# 1. 알고(구현): 백준 2960 (에라토스테네스의 체) - https://www.acmicpc.net/problem/2960
import sys

from io import StringIO
sys.stdin = StringIO('''10 7''')

input = sys.stdin.readline


def solve():

    N, K = map(int, input().split())
    nums = set(range(2, N+1))  # Set 으로 풀어봄

    del_cnt = 0
    while nums:
        P = min(nums)
        nxt = P
        while nxt <= N:  # 지울 숫자 없어도 진행
            if nxt in nums:
                nums.discard(nxt)
                del_cnt += 1
                if del_cnt == K:
                    print(nxt)
                    return
            nxt += P


solve()
# Out:
# 9

# %%
# 2. 알고(수학): 백준 1676 (팩토리얼 0의 개수) - https://www.acmicpc.net/problem/1676
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 3. 알고(Map): 백준 19583 (싸이버개강파티) - https://www.acmicpc.net/problem/19583
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 4. 알고(그리디): 백준 19941 (햄버거 분배) - https://www.acmicpc.net/problem/19941
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %% [markdown]
# ```sql
# -- 5. SQL(Lv.2): 성분으로 구분한 아이스크림 총 주문량
# -- https://school.programmers.co.kr/learn/courses/30/lessons/133026
# ```

# %%
# 1. 알고(시뮬): 백준 17142 (연구소 3) - https://www.acmicpc.net/problem/17142
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 2. 알고(DP): 백준 2631 (줄세우기) - https://www.acmicpc.net/problem/2631
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 3. 알고(그래프): 백준 1197 (최소 스패닝 트리) - https://www.acmicpc.net/problem/1197
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 4. 알고(백트래킹): 백준 2239 (스도쿠) - https://www.acmicpc.net/problem/2239
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %% [markdown]
# ```sql
# -- 5. SQL(Lv.4): 자동차 대여 기록 별 대여 금액 구하기
# -- https://school.programmers.co.kr/learn/courses/30/lessons/157338
# ```
