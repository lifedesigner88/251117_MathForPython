# %%
# 1. 알고(구현): 백준 14503 (로봇 청소기) - https://www.acmicpc.net/problem/14503
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 2. 알고(수학): 백준 1010 (다리 놓기) - https://www.acmicpc.net/problem/1010
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 3. 알고(Heap): 백준 11286 (절댓값 힙) - https://www.acmicpc.net/problem/11286
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 4. 알고(그리디): 백준 1202 (보석 도둑) - https://www.acmicpc.net/problem/1202
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %% [markdown]
# ```sql
# -- 5. SQL(Lv.2): 물고기 종류 별 잡은 수 구하기 - https://school.programmers.co.kr/learn/courses/30/lessons/293257
# ```

# %%
# 1. 알고(시뮬): 백준 20058 (마법사 상어와 파이어스톰) - https://www.acmicpc.net/problem/20058
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 2. 알고(DP): 백준 10942 (팰린드롬?) - https://www.acmicpc.net/problem/10942
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 3. 알고(그래프): 백준 11657 (타임머신) - https://www.acmicpc.net/problem/11657
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 4. 알고(백트래킹): 백준 17135 (캐슬 디펜스) - https://www.acmicpc.net/problem/17135
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %% [markdown]
# ```sql
#
# ```
