# %%
# 1. 알고(구현): 백준 2567 (색종이 - 2) - https://www.acmicpc.net/problem/2567
import sys

from io import StringIO
sys.stdin = StringIO('''4
3 7
5 2
15 7
13 14''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 2. 알고(수학): 백준 1004 (어린 왕자) - https://www.acmicpc.net/problem/1004
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 3. 알고(Map): 백준 7785 (회사에 있는 사람) - https://www.acmicpc.net/problem/7785
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 4. 알고(그리디): 백준 1449 (수리공 항승) - https://www.acmicpc.net/problem/1449
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %% [markdown]
# ```sql
# -- 5. SQL(Lv.2): 중성화 여부 파악하기 - https://school.programmers.co.kr/learn/courses/30/lessons/59409
# ```

# %%
# 1. 알고(시뮬): 백준 14502 (연구소) - https://www.acmicpc.net/problem/14502
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 2. 알고(DP): 백준 2293 (동전 1) - https://www.acmicpc.net/problem/2293
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 3. 알고(그래프): 백준 14938 (서강그라운드) - https://www.acmicpc.net/problem/14938
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %%
# 4. 알고(백트래킹): 백준 15684 (사다리 조작) - https://www.acmicpc.net/problem/15684
import sys

from io import StringIO
sys.stdin = StringIO('''''')

input = sys.stdin.readline


def solve():

    pass


solve()

# %% [markdown]
# ```sql
# -- 5. SQL(Lv.3): 즐겨찾기가 가장 많은 식당 정보 출력하기 - https://school.programmers.co.kr/learn/courses/30/lessons/131123
#
# ```
